# %% [markdown]
# # Analysis of Cell-free and HIV - Figure 5
#
# This notebook will present analyses and discussions of the GH-VAP project looking for potential microbiome causes/associations with individuals who produce broadly neutralizing antibodies to HIV; as well as everything else I can learn from the transcriptome.
#
# This specific notebook will handle the code to generate figure 5.
#
# ## Author:
#  **Mark Kowarsky**
#
#  - **Date Updated:** 2018-10-24
#
#
# #### Code cleaned by:
# - Mercedes Dalman
# - **Date Updated:** 2025-09

# %% [markdown]
# ## Imports and stylings

# %%
# %matplotlib inline
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import glob
import itertools
from collections import defaultdict
import matplotlib.dates as mdates
from matplotlib.colors import to_hex

from IPython.core.pylabtools import figsize

from scipy.interpolate import PchipInterpolator
from scipy.stats.mstats import spearmanr

# %%
# Colours from Material Design - https://material.io/tools/color/
green = "#388e3c"
light_green = "#6abf69"
dark_green = "#00600f"

blue = "#1976d2"
light_blue = "#63a4ff"
dark_blue = "#004ba0"

red = "#d32f2f"
light_red = "#ff6659"
dark_red = "#9a0007"

yellow = "#fbc02d"
light_yellow = "#fff263"
dark_yellow = "#c49000"

grey = "#616161"
light_grey = "#8e8e8e"
dark_grey = "#373737"

orange = "#f57c00"
light_orange = "#ffad42"
dark_orange = "#bb4d00"

purple = "#7b1fa2"
dark_purple = "#4a0072"
light_purple = "#ae52d4"

# %% [markdown]
# ## Design

# %%
design = pd.read_table("../tables/edgeR_design.txt", index_col=0)

a = list(design.query("bNAbs == 'Y'").index)
b = list(design.query("bNAbs == 'N'").index)
c = a + b

# %%
meta1 = pd.read_excel("../tables/Gates_metadata.xlsx", sheet_name=1)
meta1["sample"] = "SAMPLE_" + meta1["PID"].astype(str) + 14*["_1", "_2", "_3"]
meta1.set_index("sample", inplace=True)

# %% [markdown]
# ## Basic statistics

# %%
rsa = pd.read_table("../tables/samples/rSA.csv", index_col=0)
sa = pd.read_table("../tables/samples/SA.csv", index_col=0)

# %%
pre = pd.read_table("../tables/preprocess_stats.txt", index_col=0)

pre["group"] = [i.strip("B") if (i.endswith("B") and i != "Water_B") else i for i in pre.index]
pre = pre.groupby("group").sum()

# Non-human counts
nh = pd.read_table("../tables/not_human_stats.txt", names=["sample", "type", "end", "stat"])
nh["type"] = nh["type"] + "_" + nh["end"]
nh = nh.pivot(index="sample", columns="type", values="stat")

nh["group"] = [i.strip("B") if (i.endswith("B") and i != "Water_B") else i for i in nh.index]
nh = nh.groupby("group").sum()

# %%
#Order of samples
a = list(design.query("bNAbs == 'Y'").index)
b = list(design.query("bNAbs == 'N'").index)
c = a + b

# %%
pre_rsa = pd.DataFrame(index=rsa.index, columns=["raw", "cleaned", "nonhuman"])
pre_rsa.loc[rsa.index, "raw"] = pre.loc[rsa.index, "raw_fastq.1"]
pre_rsa.loc[rsa.index, "cleaned"] = 100-\
                                    100*(pre.loc[rsa.index, ["cleaned_fastq.1", 
                                                             "cleaned_fastq.U"]].sum(axis=1))/pre.loc[rsa.index, 
                                                    ["raw_fastq.1", "raw_fastq.U"]].sum(axis=1)
pre_rsa.loc[rsa.index, "cleaned_counts"] = (pre.loc[rsa.index, ["cleaned_fastq.1", 
                                                             "cleaned_fastq.U"]].sum(axis=1))
pre_rsa.loc[rsa.index, "nonhuman"] = 100*(nh.loc[rsa.index, ["human_genome_fastq.1", 
                                                             "human_genome_fastq.U"]].sum(axis=1))/pre.loc[rsa.index, 
                                                    ["cleaned_fastq.1", "cleaned_fastq.U"]].sum(axis=1)
pre_rsa["human"] = 100 - pre_rsa["nonhuman"]
pre_rsa["human_counts"] = pre_rsa["cleaned_counts"] - nh.loc[rsa.index, ["human_genome_fastq.1", 
                                                             "human_genome_fastq.U"]].sum(axis=1)

pre_rsa = pre_rsa.sort_index()
pre_rsa["Subject"] = [i.split("_")[1] for i in pre_rsa.index]
pre_rsa["Subject"] = [i[:-1] if "water" in i else i for i in pre_rsa["Subject"]]

pre_rsa = pre_rsa.loc[c + list(rsa.index.difference(c))] # Preserve order from before

# %%
meta1["other_name"] = meta1["PID"].astype(str) + "_" + meta1["visit code"].astype(str)
meta1["old_name"] = meta1.index
m = meta1.set_index("other_name")

# %%
I = sa.index.intersection(pre.index).intersection(nh.index)

# sums 
raw_sum    = pre.loc[I, ["raw_fastq.1", "raw_fastq.U"]].sum(axis=1)
clean_sum  = pre.loc[I, ["cleaned_fastq.1", "cleaned_fastq.U"]].sum(axis=1)
human_sum  = nh.loc[I,  ["human_genome_fastq.1", "human_genome_fastq.U"]].sum(axis=1)

# percentages 
pct_cleaned   = 100 - 100 * clean_sum.div(raw_sum.where(raw_sum > 0, np.nan))
pct_nonhuman  = 100 * human_sum.div(clean_sum.where(clean_sum > 0, np.nan))  # same as your original "nonhuman"


pre_sa = pd.DataFrame({
    "raw":            pre.loc[I, "raw_fastq.1"],
    "cleaned":        pct_cleaned,
    "cleaned_counts": clean_sum,
    "nonhuman":       pct_nonhuman,
}, index=I)

pre_sa["human"] = 100 - pre_sa["nonhuman"]

pre_sa = pre_sa.sort_index()
pre_sa["Subject"] = pre_sa.index.str.split("_").str[0]

# remap non-Water indices via m['old_name']
not_water = pre_sa.index[pre_sa["Subject"] != "Water"]
water     = pre_sa.index[pre_sa["Subject"] == "Water"]

mapped_series   = m.reindex(not_water)["old_name"]
mapped_nonwater = [mapped_series.get(i, i) if pd.notna(mapped_series.get(i, np.nan)) else i
                   for i in not_water]

pre_sa.index = mapped_nonwater + water.tolist()

# %% [markdown]
# ## Transcriptome

# %%
genes = pd.read_table("../tables/gene_counts.txt", index_col=0).T

genes_duprm = genes.copy().loc[[s for s in genes.index if "duprm" in s]]
genes_duprm["sample"] = [s.split(".")[0] for s in genes_duprm.index]
genes_duprm = genes_duprm.groupby("sample").sum().T

genes = genes.copy().loc[[s for s in genes.index if "duprm" not in s]]
genes["sample"] = [s.split(".")[0] for s in genes.index]
genes = genes.groupby("sample").sum().T

# %%
just_genes = genes.iloc[:-5]
just_genes = genes.loc[[g for g in genes.index if "ENSG" in g]]
cpm = (1e6*just_genes.div(just_genes.sum()))
logCPM = np.log10(cpm+1)

X = logCPM.loc[:, meta1.index.difference(["SAMPLE_100200_1"])].T

# %%
#just_genes.loc[:, X.index].to_csv("just_gene_counts.txt", sep="\t") # Just good samples here

# %% [markdown]
# # Panel A

# %% [markdown]
# ### Differential infectome analysis

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("./")

import run_modelling_cleaned as rm

# %%
ia = pd.read_pickle("../tables/accession_taxid.pkl") 

print("accession_taxid rows:", ia.shape[0])
# Out:
# accession_taxid rows: 1962798

# %% [markdown]
# ## Build cm

# %%
DOMAINS = ["bacteria", "archaea", "viruses"]
RANKS = ["species", "genus", "family", "order", "class", "phylum"]

domain_results = {}

for DOMAIN in DOMAINS:
    counts_taxid, meta, use_files = rm.build_counts_for_domain(DOMAIN, ia)

    print(f"\n=== {DOMAIN} ===")
    print("Files used:", len(use_files))
    print("Taxid matrix:", counts_taxid.shape)
    print(meta["group"].value_counts())

    # save taxid-level
    counts_taxid.to_csv(f"just_{DOMAIN}_counts.taxid.txt", sep="\t")

    # save ranks
    rank_tables = {}
    for rank in RANKS:
        xr = rm.collapse_to_rank(counts_taxid, rank)
        xr.to_csv(f"just_{DOMAIN}_counts_{rank}.txt", sep="\t")
        rank_tables[rank] = xr
        print(rank, xr.shape)

    domain_results[DOMAIN] = {
        "counts_taxid": counts_taxid,
        "meta": meta,
        "rank_tables": rank_tables
    }
# Out:
# === bacteria ===
# Files used: 55
# Taxid matrix: (144013, 55)
# group
# plasma    41
# ntc        8
# water      6
# Name: count, dtype: int64
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 57 was translated into 3409587
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 417 was translated into 17
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 1532 was translated into 33035
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 1551 was translated into 36839
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 1560 was translated into 1525
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 1900 was translated into 1961
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 1929 was translated into 36817
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2384 was translated into 3100283
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 28160 was translated into 67857
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 29398 was translated into 1614
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 29570 was translated into 77097
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 33961 was translated into 1614
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 37480 was translated into 67362
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 45461 was translated into 37919
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 46170 was translated into 1280
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 48937 was translated into 48935
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 50340 was translated into 53407
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 50728 was translated into 2036
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 52765 was translated into 301953
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 52766 was translated into 301953
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 53423 was translated into 28262
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 54064 was translated into 334542
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 58134 was translated into 29370
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 59244 was translated into 58100
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 59917 was translated into 1836
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 62928 was translated into 418699
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 65497 was translated into 2893586
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 66372 was translated into 68174
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 66857 was translated into 1898
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 66873 was translated into 116188
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 66889 was translated into 28893
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 66963 was translated into 1093625
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 67262 was translated into 67260
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 67295 was translated into 1911
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 67308 was translated into 1936
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 67334 was translated into 67367
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 67349 was translated into 1894
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 67382 was translated into 1887
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 68043 was translated into 1920
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 68172 was translated into 67303
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 68178 was translated into 1894
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 68189 was translated into 68174
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 68202 was translated into 1919
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 68204 was translated into 36817
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 68210 was translated into 47760
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 68243 was translated into 45398
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 68570 was translated into 1971
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 72759 was translated into 1280
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /home/mercedes/micromamba/envs/marksouthafrica-ete-r/lib/python3.10/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid
import rpy2.robjects as ro
from rpy2.robjects import pandas2ri
from rpy2.robjects.conversion import localconverter

ro.r("library(edgeR)")

ro.r("""
read_counts_df <- function(x) {
  y <- DGEList(counts=x, genes=rownames(x))
  keep <- rowSums(cpm(y) > 5) >= 10
  y <- y[keep,, keep.lib.sizes=FALSE]
  y <- calcNormFactors(y)
  return(y)
}

run_de <- function(y, design) {
  y <- estimateDisp(y, design)
  fit <- glmQLFit(y, design)
  return(fit)
}
""")
# Out:
# R callback write-console: Loading required package: limma

# %%
DOMAIN = "bacteria"
rank = "genus"
counts = domain_results[DOMAIN]["rank_tables"][rank]
meta = domain_results[DOMAIN]["meta"]

design_df = pd.read_table("edgeR_design.txt", index_col=0)

res_bnabs, logcpm_bnabs, d_plasma = rm.edger_bnabs_plasma(counts, meta, design_df, bNAbs_ref=None)
res_bnabs.head()
# Out:
#                                    genes     logFC     logCPM          F  \
# Paraclostridium          Paraclostridium  2.480353   8.902199  30.259104
# Limosilactobacillus  Limosilactobacillus -3.781026  11.788221  28.332158
# Shimwellia                    Shimwellia  2.914663   6.386779  27.439862
# Caldibacillus              Caldibacillus -2.373254  10.546186  26.909897
# Tepidiphilus                Tepidiphilus -2.138279   7.496007  25.433189
#
#                        PValue       FDR
# Paraclostridium      0.000002  0.002682
# Limosilactobacillus  0.000004  0.002682
# Shimwellia           0.000005  0.002682
# Caldibacillus        0.000006  0.002682
# Tepidiphilus         0.000008  0.003099

# %%
# build this once per domain/rank
genus_table = domain_results[DOMAIN]["rank_tables"]["genus"]
genus_name_to_taxid = rm.build_name_to_taxid_map(genus_table.index, rank="genus")

# %%
res_bg, logcpm, meta_pw = rm.edger_plasma_vs_water(counts, meta)

# %%
# Add family annotations to a result table indexed by genus name.
res_bg_fam    = rm.add_phylum_to_res_from_map(res_bg, genus_name_to_taxid)
res_bnabs_fam = rm.add_phylum_to_res_from_map(res_bnabs, genus_name_to_taxid)

res_bg_fam['family'] = res_bg_fam ['phylum']
res_bnabs_fam['family'] = res_bnabs_fam['phylum']

# %%
# Use this to make palette for families
shared_palette, top_fams_global = rm.build_shared_family_palette(
    [res_bg_fam, res_bnabs_fam],
    fdr_thr=0.05,
    lfc_thr=1.0,
    top_n_families=12,
    base_palette="tab20",
    other_color="wheat",
    unknown_color="silver"
)

res_bg_fam2    = rm.apply_family_plot_bucket(res_bg_fam, top_fams_global)
res_bnabs_fam2 = rm.apply_family_plot_bucket(res_bnabs_fam, top_fams_global)

# %%
families_to_highlight = ["Bacillota",
"Pseudomonadota",
"Actinomycetota",
"Fusobacteriota",
"Bacteroidota",
"Mycoplasmatota",
"Thermodesulfobacteriota"]
                        
#  want the categories beforehand to build palette safely)
def set_family_plot_from_highlight(res, highlight_families):
    df = res.copy()
    df["family_plot"] = np.where(df["family"].isin(highlight_families), df["family"], "Other")
    df.loc[df["family"].eq("Unknown"), "family_plot"] = "Unknown"
    return df

res_bg_fam2_h = set_family_plot_from_highlight(res_bg_fam2, families_to_highlight)
res_bnabs_fam2_h = set_family_plot_from_highlight(res_bnabs_fam2, families_to_highlight)

# ensure palette covers EVERYTHING that might show up
families_present = set(res_bg_fam2["family"].unique()) | set(res_bnabs_fam2["family"].unique())
shared_palette = rm.ensure_palette_has_families(shared_palette, families_present)


rm.volcano_plot_family_fixed2(
    res_bnabs_fam2,
    palette=shared_palette,
    title="fig_1_bnab_phylum_larger",
    mode="fdr_lfc",
    fdr_thr=5e-2,
    lfc_thr=1.0,
    show_cutoffs=True,
    figsize=(7, 6),
    highlight_families=families_to_highlight
)

# %% [markdown]
# # Panel B

# %% [markdown]
# ## Infectome - GB virus C

# %%
pegivirus_r = pd.read_csv('../tables/pegivirus_counts.csv', index_col = 0)

# %%
y = pegivirus_r.sum()
y = 1e3*y/(pre_rsa["cleaned_counts"].loc[X.index] - pre_rsa["human_counts"].loc[X.index]) # Normalize it like cfHIV

# %%
a = list(design.query("bNAbs == 'Y'").index)
b = list(design.query("bNAbs == 'N'").index)

c = a + b
c = [i for i in c if i != "SAMPLE_100200_1"]

# %%
GBVC_heatmap = pd.DataFrame(
    index=meta1.loc[a, "PID"].unique(),
    columns=["1","2","3"],
    dtype=float
)

for s in meta1.loc[a].index.intersection(c).intersection(y.index):
    pid = meta1.loc[s, "PID"]
    arm = s.split("_")[2]           
    GBVC_heatmap.loc[pid, arm] = float(y.loc[s])

# %%
# bNAb unproductive — build table
uGBVC_heatmap = pd.DataFrame(
    index=meta1.loc[b, "PID"].unique(),
    columns=["1", "2", "3"],
    dtype=float
)

for pid, sub in meta1.loc[b].groupby("PID"):
    for s in sub.index:
        if s in c:
            uGBVC_heatmap.loc[pid, s.split("_")[2]] = float(y.loc[s])

# %%
# Paired line plots (productive vs unproductive)
f, axarr = plt.subplots(ncols=2, figsize=(10, 6), sharey=True)

GBVC_heatmap.T.plot(legend=False, color=red, marker='D', markersize=10,
                    markerfacecoloralt="white", fillstyle="left", markeredgewidth=0, ax=axarr[0])
GBVC_heatmap.T.plot(legend=False, color=red, marker='D', linewidth=0, markersize=10,
                    markerfacecoloralt="white", fillstyle="none", markeredgewidth=1.5, ax=axarr[0])

uGBVC_heatmap.T.plot(legend=False, color=blue, marker='D', markersize=10,
                     markerfacecoloralt="white", fillstyle="right", markeredgewidth=0, ax=axarr[1])
uGBVC_heatmap.T.plot(legend=False, color=blue, marker='D', linewidth=0, markersize=10,
                     markerfacecoloralt="white", fillstyle="none", markeredgewidth=1.5, ax=axarr[1])

axarr[0].set_title("bNABs")
axarr[0].set_ylabel("cfGBV-C (normalized)")
axarr[0].axhline(0.5, color='k', ls="dashed", lw=1)
axarr[0].set_xticks([0, 1, 2])
axarr[0].set_xticklabels(["~0.5", "~1", "~3"])
axarr[0].set_xlabel("years post infection")

axarr[1].set_title("few bNABs")
axarr[1].axhline(0.5, color='k', ls="dashed", lw=1)
axarr[1].set_xticks([0, 1, 2])
axarr[1].set_xticklabels(["~0.5", "~1", "~3"])
axarr[1].set_xlabel("years post infection")

plt.yscale("log")
sns.despine()
plt.tight_layout()
os.makedirs('../figures/figure5/panel_A/', exist_ok = True)
plt.savefig("../figures/figure5/panel_A/GBVC.svg")
plt.show()
